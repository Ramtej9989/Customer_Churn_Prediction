# %%
import pandas as pd

df = pd.read_csv("../data/raw/customer_churn.csv")

df.head()
df.shape
df.columns
df.describe()
df.info()
df.duplicated().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         10000 non-null  str
#  1   Gender             10000 non-null  str
#  2   Age                10000 non-null  int64
#  3   SeniorCitizen      10000 non-null  int64
#  4   Partner            10000 non-null  str
#  5   Dependents         10000 non-null  str
#  6   TenureMonths       10000 non-null  int64
#  7   PhoneService       10000 non-null  str
#  8   InternetService    9022 non-null   str
#  9   OnlineSecurity     10000 non-null  str
#  10  OnlineBackup       10000 non-null  str
#  11  DeviceProtection   10000 non-null  str
#  12  TechSupport        10000 non-null  str
#  13  StreamingTV        10000 non-null  str
#  14  StreamingMovies    10000 non-null  str
#  15  Contract           10000 non-null  str
#  16  PaymentMethod      10000 non-null  str
#  17  MonthlyCharges     10000 non-null  float64
#  18  TotalCharges       10000 non-null  float64
#  19  SupportTickets     10000 non-null  int64
#  20  SatisfactionScore  10000 non-null  int64
#  21  Churn              10000 non-null  str
# dtypes: float64(2), int64(5), str(15)
# memory usage: 1.7 MB
# np.int64(0)

# %%
df.describe()
# Out:
#                 Age  SeniorCitizen  TenureMonths  MonthlyCharges  \
# count  10000.000000   10000.000000  10000.000000    10000.000000
# mean      48.712300       0.324100     36.295400       62.010633
# std       18.203474       0.468061     21.182564       22.233825
# min       18.000000       0.000000      0.000000       20.000000
# 25%       33.000000       0.000000     18.000000       46.757500
# 50%       48.000000       0.000000     36.000000       62.720000
# 75%       65.000000       1.000000     55.000000       77.460000
# max       80.000000       1.000000     72.000000      138.110000
#
#        TotalCharges  SupportTickets  SatisfactionScore
# count  10000.000000    10000.000000       10000.000000
# mean    2255.991407        1.303300           3.007200
# std     1625.237672        1.136415           1.421038
# min        0.000000        0.000000           1.000000
# 25%      925.570000        0.000000           2.000000
# 50%     1965.385000        1.000000           3.000000
# 75%     3318.272500        2.000000           4.000000
# max     8690.890000        8.000000           5.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         10000 non-null  str
#  1   Gender             10000 non-null  str
#  2   Age                10000 non-null  int64
#  3   SeniorCitizen      10000 non-null  int64
#  4   Partner            10000 non-null  str
#  5   Dependents         10000 non-null  str
#  6   TenureMonths       10000 non-null  int64
#  7   PhoneService       10000 non-null  str
#  8   InternetService    9022 non-null   str
#  9   OnlineSecurity     10000 non-null  str
#  10  OnlineBackup       10000 non-null  str
#  11  DeviceProtection   10000 non-null  str
#  12  TechSupport        10000 non-null  str
#  13  StreamingTV        10000 non-null  str
#  14  StreamingMovies    10000 non-null  str
#  15  Contract           10000 non-null  str
#  16  PaymentMethod      10000 non-null  str
#  17  MonthlyCharges     10000 non-null  float64
#  18  TotalCharges       10000 non-null  float64
#  19  SupportTickets     10000 non-null  int64
#  20  SatisfactionScore  10000 non-null  int64
#  21  Churn              10000 non-null  str
# dtypes: float64(2), int64(5), str(15)
# memory usage: 1.7 MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Churn"].value_counts()
# Out:
# Churn
# Yes    5326
# No     4674
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize=True) * 100
# Out:
# Churn
# Yes    53.26
# No     46.74
# Name: proportion, dtype: float64

# %%
df.nunique()
# Out:
# CustomerID           10000
# Gender                   2
# Age                     63
# SeniorCitizen            2
# Partner                  2
# Dependents               2
# TenureMonths            73
# PhoneService             2
# InternetService          3
# OnlineSecurity           3
# OnlineBackup             3
# DeviceProtection         3
# TechSupport              3
# StreamingTV              3
# StreamingMovies          3
# Contract                 3
# PaymentMethod            4
# MonthlyCharges        5529
# TotalCharges          9812
# SupportTickets           9
# SatisfactionScore        5
# Churn                    2
# dtype: int64
